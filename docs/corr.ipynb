# %%
import pandas as pd 
df=pd.read_csv("flight_data_2018_to_2022.csv", sep=";" , low_memory=False )

# %%
df_min=df.sample(10000)

# %%
df_min.to_csv("sample10000.csv")

# %%
ratio_na=(df_min.isna().sum()/df_min.shape[0])

# %%
ratio_na.to_csv("ratio_na.csv")

# %%
columns_useful=ratio_na[ratio_na<0.5].index

# %%
df=df[columns_useful]

# %%
corr = df.corr()

# %%
# Out:
#                                  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# Year                              NaN      NaN    NaN         NaN        NaN
# Quarter                           NaN      NaN    NaN         NaN        NaN
# Month                             NaN      NaN    NaN         NaN        NaN
# DayofMonth                        NaN      NaN    NaN    1.000000  -0.009476
# DayOfWeek                         NaN      NaN    NaN   -0.009476   1.000000
# DOT_ID_Marketing_Airline          NaN      NaN    NaN   -0.010540   0.005186
# Flight_Number_Marketing_Airline   NaN      NaN    NaN   -0.046841   0.011267
# DOT_ID_Operating_Airline          NaN      NaN    NaN   -0.009182  -0.000523
# Flight_Number_Operating_Airline   NaN      NaN    NaN   -0.046825   0.011256
# OriginAirportID                   NaN      NaN    NaN   -0.002255   0.005799
# OriginAirportSeqID                NaN      NaN    NaN   -0.002255   0.005799
# OriginCityMarketID                NaN      NaN    NaN   -0.002661   0.004366
# OriginStateFips                   NaN      NaN    NaN   -0.000422  -0.006129
# OriginWac                         NaN      NaN    NaN    0.003859   0.001870
# DestAirportID                     NaN      NaN    NaN   -0.002195   0.005566
# DestAirportSeqID                  NaN      NaN    NaN   -0.002195   0.005566
# DestCityMarketID                  NaN      NaN    NaN   -0.002447   0.004723
# DestStateFips                     NaN      NaN    NaN   -0.000625  -0.005335
# DestWac                           NaN      NaN    NaN    0.003932   0.001812
# CRSDepTime                        NaN      NaN    NaN   -0.005893   0.010295
# DepTime                           NaN      NaN    NaN   -0.015490   0.010072
# DepDelay                          NaN      NaN    NaN   -0.116249   0.037846
# DepDelayMinutes                   NaN      NaN    NaN   -0.105954   0.032789
# DepDel15                          NaN      NaN    NaN   -0.178963   0.052721
# DepartureDelayGroups              NaN      NaN    NaN   -0.161846   0.048800
# TaxiOut                           NaN      NaN    NaN    0.001211   0.029189
# WheelsOff                         NaN      NaN    NaN   -0.013325   0.009467
# WheelsOn                          NaN      NaN    NaN    0.008272  -0.000359
# TaxiIn                            NaN      NaN    NaN   -0.066019   0.031105
# CRSArrTime                        NaN      NaN    NaN   -0.001065   0.007274
# ArrTime                           NaN      NaN    NaN    0.010392  -0.000958
# ArrDelay                          NaN      NaN    NaN   -0.125359   0.047940
# ArrDelayMinutes                   NaN      NaN    NaN   -0.102996   0.037932
# ArrDel15                          NaN      NaN    NaN   -0.168697   0.061502
# ArrivalDelayGroups                NaN      NaN    NaN   -0.163718   0.061161
# Cancelled                         NaN      NaN    NaN   -0.096996   0.064372
# Diverted                          NaN      NaN    NaN    0.000125   0.009592
# CRSElapsedTime                    NaN      NaN    NaN   -0.012205   0.009907
# ActualElapsedTime                 NaN      NaN    NaN   -0.032114   0.016618
# AirTime                           NaN      NaN    NaN   -0.026159   0.009540
# Flights                           NaN      NaN    NaN         NaN        NaN
# Distance                          NaN      NaN    NaN   -0.014780   0.011702
# DistanceGroup                     NaN      NaN    NaN   -0.014742   0.011813
# DivAirportLandings                NaN      NaN    NaN   -0.003113   0.003591
#
#                                  DOT_ID_Marketing_Airline  \
# Year                                                  NaN
# Quarter                                               NaN
# Month                                                 NaN
# DayofMonth                                      -0.010540
# DayOfWeek                                        0.005186
# DOT_ID_Marketing_Airline                         1.000000
# Flight_Number_Marketing_Airline                 -0.085099
# DOT_ID_Operating_Airline                         0.733310
# Flight_Number_Operating_Airline                 -0.085102
# OriginAirportID                                  0.013178
# OriginAirportSeqID                               0.013178
# OriginCityMarketID                               0.050846
# OriginStateFips                                  0.023276
# OriginWac                                       -0.132540
# DestAirportID                                    0.013298
# DestAirportSeqID                                 0.013298
# DestCityMarketID                                 0.050936
# DestStateFips                                    0.023226
# DestWac                                         -0.132449
# CRSDepTime                                       0.018303
# DepTime                                          0.011440
# DepDelay                                         0.037133
# DepDelayMinutes                                  0.047945
# DepDel15                                         0.034705
# DepartureDelayGroups                             0.044466
# TaxiOut                                          0.141291
# WheelsOff                                        0.009493
# WheelsOn                                        -0.008193
# TaxiIn                                           0.129881
# CRSArrTime                                      -0.004847
# ArrTime                                         -0.011986
# ArrDelay                                         0.061968
# ArrDelayMinutes                                  0.059895
# ArrDel15                                         0.065989
# ArrivalDelayGroups                               0.075208
# Cancelled                                        0.011814
# Diverted                                         0.005574
# CRSElapsedTime                                   0.147578
# ActualElapsedTime                                0.168570
# AirTime                                          0.138197
# Flights                                               NaN
# Distance                                         0.127123
# DistanceGroup                                    0.128419
# DivAirportLandings                               0.004442
#
#                                  Flight_Number_Marketing_Airline  \
# Year                                                         NaN
# Quarter                                                      NaN
# Month                                                        NaN
# DayofMonth                                             -0.046841
# DayOfWeek                                               0.011267
# DOT_ID_Marketing_Airline                               -0.085099
# Flight_Number_Marketing_Airline                         1.000000
# DOT_ID_Operating_Airline                                0.464240
# Flight_Number_Operating_Airline                         0.999988
# OriginAirportID                                        -0.037583
# OriginAirportSeqID                                     -0.037583
# OriginCityMarketID                                      0.012287
# OriginStateFips                                         0.120991
# OriginWac                                              -0.020553
# DestAirportID                                          -0.058625
# DestAirportSeqID                                       -0.058625
# DestCityMarketID                                       -0.001776
# DestStateFips                                           0.122182
# DestWac                                                -0.022041
# CRSDepTime                                             -0.006178
# DepTime                                                 0.002180
# DepDelay                                                0.010338
# DepDelayMinutes                                         0.015132
# DepDel15                                               -0.009825
# DepartureDelayGroups                                    0.005024
# TaxiOut                                                 0.135382
# WheelsOff                                               0.013401
# WheelsOn                                                0.002789
# TaxiIn                                                  0.015571
# CRSArrTime                                             -0.004157
# ArrTime                                                 0.008799
# ArrDelay                                                0.019388
# ArrDelayMinutes                                         0.022282
# ArrDel15                                                0.010351
# ArrivalDelayGroups                                      0.017321
# Cancelled                                               0.055619
# Diverted                                                0.002347
# CRSElapsedTime                                         -0.355966
# ActualElapsedTime                                      -0.351024
# AirTime                                                -0.380502
# Flights                                                      NaN
# Distance                                               -0.397813
# DistanceGroup                                          -0.395942
# DivAirportLandings                                      0.006881
#
#                                  DOT_ID_Operating_Airline  \
# Year                                                  NaN
# Quarter                                               NaN
# Month                                                 NaN
# DayofMonth                                      -0.009182
# DayOfWeek                                       -0.000523
# DOT_ID_Marketing_Airline                         0.733310
# Flight_Number_Marketing_Airline                  0.464240
# DOT_ID_Operating_Airline                         1.000000
# Flight_Number_Operating_Airline                  0.464249
# OriginAirportID                                 -0.034355
# OriginAirportSeqID                              -0.034355
# OriginCityMarketID                               0.041996
# OriginStateFips                                  0.117743
# OriginWac                                       -0.162750
# DestAirportID                                   -0.034412
# DestAirportSeqID                                -0.034412
# DestCityMarketID                                 0.041952
# DestStateFips                                    0.117667
# DestWac                                         -0.162760
# CRSDepTime                                       0.010360
# DepTime                                          0.009100
# DepDelay                                         0.028841
# DepDelayMinutes                                  0.042302
# DepDel15                                         0.007830
# DepartureDelayGroups                             0.027530
# TaxiOut                                          0.228838
# WheelsOff                                        0.015624
# WheelsOn                                        -0.008176
# TaxiIn                                           0.130959
# CRSArrTime                                      -0.009297
# ArrTime                                         -0.006757
# ArrDelay                                         0.056585
# ArrDelayMinutes                                  0.058852
# ArrDel15                                         0.050964
# ArrivalDelayGroups                               0.064068
# Cancelled                                        0.037176
# Diverted                                         0.006893
# CRSElapsedTime                                  -0.102746
# ActualElapsedTime                               -0.080561
# AirTime                                         -0.129564
# Flights                                               NaN
# Distance                                        -0.150774
# DistanceGroup                                   -0.151185
# DivAirportLandings                               0.007638
#
#                                  Flight_Number_Operating_Airline  \
# Year                                                         NaN
# Quarter                                                      NaN
# Month                                                        NaN
# DayofMonth                                             -0.046825
# DayOfWeek                                               0.011256
# DOT_ID_Marketing_Airline                               -0.085102
# Flight_Number_Marketing_Airline                         0.999988
# DOT_ID_Operating_Airline                                0.464249
# Flight_Number_Operating_Airline                         1.000000
# OriginAirportID                                        -0.037584
# OriginAirportSeqID                                     -0.037584
# OriginCityMarketID                                      0.012284
# OriginStateFips                                         0.120993
# OriginWac                                              -0.020561
# DestAirportID                                          -0.058625
# DestAirportSeqID                                       -0.058625
# DestCityMarketID                                       -0.001775
# DestStateFips                                           0.122184
# DestWac                                                -0.022047
# CRSDepTime                                             -0.006188
# DepTime                                                 0.002175
# DepDelay                                                0.010368
# DepDelayMinutes                                         0.015159
# DepDel15                                               -0.009801
# DepartureDelayGroups                                    0.005057
# TaxiOut                                                 0.135389
# WheelsOff                                               0.013397
# WheelsOn                                                0.002785
# TaxiIn                                                  0.015570
# CRSArrTime                                             -0.004166
# ArrTime                                                 0.008795
# ArrDelay                                                0.019418
# ArrDelayMinutes                                         0.022309
# ArrDel15                                                0.010375
# ArrivalDelayGroups                                      0.017353
# Cancelled                                               0.055612
# Diverted                                                0.002346
# CRSElapsedTime                                         -0.355969
# ActualElapsedTime                                      -0.351027
# AirTime                                                -0.380506
# Flights                                                      NaN
# Distance                                               -0.397817
# DistanceGroup                                          -0.395946
# DivAirportLandings                                      0.006880
#
#                                  OriginAirportID  ...  ArrivalDelayGroups  \
# Year                                         NaN  ...                 NaN
# Quarter                                      NaN  ...                 NaN
# Month                                        NaN  ...                 NaN
# DayofMonth                             -0.002255  ...           -0.163718
# DayOfWeek                               0.005799  ...            0.061161
# DOT_ID_Marketing_Airline                0.013178  ...            0.075208
# Flight_Number_Marketing_Airline        -0.037583  ...            0.017321
# DOT_ID_Operating_Airline               -0.034355  ...            0.064068
# Flight_Number_Operating_Airline        -0.037584  ...            0.017353
# OriginAirportID                         1.000000  ...           -0.016786
# OriginAirportSeqID                      1.000000  ...           -0.016787
# OriginCityMarketID                      0.632820  ...           -0.008001
# OriginStateFips                        -0.109528  ...            0.001952
# OriginWac                               0.212126  ...           -0.039622
# DestAirportID                           0.004826  ...           -0.000388
# DestAirportSeqID                        0.004826  ...           -0.000388
# DestCityMarketID                       -0.016998  ...            0.011947
# DestStateFips                          -0.031721  ...            0.010665
# DestWac                                 0.110528  ...           -0.049102
# CRSDepTime                             -0.038100  ...            0.073008
# DepTime                                -0.039333  ...            0.137391
# DepDelay                               -0.010274  ...            0.784651
# DepDelayMinutes                        -0.007075  ...            0.771384
# DepDel15                               -0.017217  ...            0.694145
# DepartureDelayGroups                   -0.014409  ...            0.919238
# TaxiOut                                -0.045538  ...            0.271323
# WheelsOff                              -0.043629  ...            0.133617
# WheelsOn                               -0.013122  ...            0.038032
# TaxiIn                                  0.025400  ...            0.177235
# CRSArrTime                             -0.014488  ...            0.057118
# ArrTime                                -0.011958  ...            0.029167
# ArrDelay                               -0.010946  ...            0.853398
# ArrDelayMinutes                        -0.007417  ...            0.800193
# ArrDel15                               -0.016584  ...            0.771476
# ArrivalDelayGroups                     -0.016786  ...            1.000000
# Cancelled                              -0.022605  ...                 NaN
# Diverted                                0.003246  ...                 NaN
# CRSElapsedTime                          0.056155  ...           -0.015727
# ActualElapsedTime                       0.055576  ...            0.062454
# AirTime                                 0.060896  ...            0.005769
# Flights                                      NaN  ...                 NaN
# Distance                                0.081689  ...           -0.007196
# DistanceGroup                           0.086570  ...           -0.007830
# DivAirportLandings                      0.005184  ...            0.006861
#
#                                  Cancelled  Diverted  CRSElapsedTime  \
# Year                                   NaN       NaN             NaN
# Quarter                                NaN       NaN             NaN
# Month                                  NaN       NaN             NaN
# DayofMonth                       -0.096996  0.000125       -0.012205
# DayOfWeek                         0.064372  0.009592        0.009907
# DOT_ID_Marketing_Airline          0.011814  0.005574        0.147578
# Flight_Number_Marketing_Airline   0.055619  0.002347       -0.355966
# DOT_ID_Operating_Airline          0.037176  0.006893       -0.102746
# Flight_Number_Operating_Airline   0.055612  0.002346       -0.355969
# OriginAirportID                  -0.022605  0.003246        0.056155
# OriginAirportSeqID               -0.022606  0.003246        0.056155
# OriginCityMarketID               -0.013155  0.002428        0.017762
# OriginStateFips                   0.024505 -0.007029       -0.040556
# OriginWac                        -0.056891 -0.000087       -0.058350
# DestAirportID                    -0.023743 -0.001035        0.093638
# DestAirportSeqID                 -0.023744 -0.001035        0.093638
# DestCityMarketID                 -0.017726  0.000112        0.005323
# DestStateFips                     0.023365  0.003300       -0.089616
# DestWac                          -0.056531  0.001155        0.072469
# CRSDepTime                       -0.014402 -0.002890       -0.028576
# DepTime                           0.006543 -0.000327       -0.036509
# DepDelay                          0.021827  0.016421        0.015995
# DepDelayMinutes                   0.021599  0.015690        0.012598
# DepDel15                          0.016811  0.018267        0.026950
# DepartureDelayGroups              0.025079  0.021399        0.021772
# TaxiOut                           0.007802  0.012325        0.031396
# WheelsOff                         0.008049 -0.000211       -0.047976
# WheelsOn                               NaN  0.000497        0.013168
# TaxiIn                                 NaN  0.017664        0.079305
# CRSArrTime                       -0.017034 -0.000038        0.026758
# ArrTime                                NaN -0.000765        0.010872
# ArrDelay                               NaN       NaN       -0.021108
# ArrDelayMinutes                        NaN       NaN        0.002516
# ArrDel15                               NaN       NaN        0.006929
# ArrivalDelayGroups                     NaN       NaN       -0.015727
# Cancelled                         1.000000 -0.011882       -0.023376
# Diverted                         -0.011882  1.000000        0.011853
# CRSElapsedTime                   -0.023376  0.011853        1.000000
# ActualElapsedTime                      NaN       NaN        0.979480
# AirTime                                NaN       NaN        0.988981
# Flights                                NaN       NaN             NaN
# Distance                         -0.030597  0.011237        0.975438
# DistanceGroup                    -0.030275  0.010892        0.963376
# DivAirportLandings                0.051526  0.318472       -0.004650
#
#                                  ActualElapsedTime   AirTime  Flights  \
# Year                                           NaN       NaN      NaN
# Quarter                                        NaN       NaN      NaN
# Month                                          NaN       NaN      NaN
# DayofMonth                               -0.032114 -0.026159      NaN
# DayOfWeek                                 0.016618  0.009540      NaN
# DOT_ID_Marketing_Airline                  0.168570  0.138197      NaN
# Flight_Number_Marketing_Airline          -0.351024 -0.380502      NaN
# DOT_ID_Operating_Airline                 -0.080561 -0.129564      NaN
# Flight_Number_Operating_Airline          -0.351027 -0.380506      NaN
# OriginAirportID                           0.055576  0.060896      NaN
# OriginAirportSeqID                        0.055576  0.060896      NaN
# OriginCityMarketID                        0.021814  0.020847      NaN
# OriginStateFips                          -0.041398 -0.056432      NaN
# OriginWac                                -0.067303 -0.045196      NaN
# DestAirportID                             0.088930  0.098957      NaN
# DestAirportSeqID                          0.088930  0.098957      NaN
# DestCityMarketID                          0.007213  0.019573      NaN
# DestStateFips                            -0.081480 -0.090348      NaN
# DestWac                                   0.047883  0.065700      NaN
# CRSDepTime                               -0.026764 -0.016398      NaN
# DepTime                                  -0.033125 -0.024414      NaN
# DepDelay                                  0.022605  0.011708      NaN
# DepDelayMinutes                           0.019214  0.008206      NaN
# DepDel15                                  0.033926  0.024375      NaN
# DepartureDelayGroups                      0.029927  0.017441      NaN
# TaxiOut                                   0.146441  0.001723      NaN
# WheelsOff                                -0.042118 -0.037427      NaN
# WheelsOn                                  0.016799  0.024890      NaN
# TaxiIn                                    0.164644  0.062866      NaN
# CRSArrTime                                0.027037  0.035912      NaN
# ArrTime                                   0.013549  0.021769      NaN
# ArrDelay                                  0.040878 -0.003669      NaN
# ArrDelayMinutes                           0.042294  0.006871      NaN
# ArrDel15                                  0.079180  0.022941      NaN
# ArrivalDelayGroups                        0.062454  0.005769      NaN
# Cancelled                                      NaN       NaN      NaN
# Diverted                                       NaN       NaN      NaN
# CRSElapsedTime                            0.979480  0.988981      NaN
# ActualElapsedTime                         1.000000  0.984307      NaN
# AirTime                                   0.984307  1.000000      NaN
# Flights                                        NaN       NaN      NaN
# Distance                                  0.963585  0.981829      NaN
# DistanceGroup                             0.951355  0.969650      NaN
# DivAirportLandings                        0.003841  0.004138      NaN
#
#                                  Distance  DistanceGroup  DivAirportLandings
# Year                                  NaN            NaN                 NaN
# Quarter                               NaN            NaN                 NaN
# Month                                 NaN            NaN                 NaN
# DayofMonth                      -0.014780      -0.014742           -0.003113
# DayOfWeek                        0.011702       0.011813            0.003591
# DOT_ID_Marketing_Airline         0.127123       0.128419            0.004442
# Flight_Number_Marketing_Airline -0.397813      -0.395942            0.006881
# DOT_ID_Operating_Airline        -0.150774      -0.151185            0.007638
# Flight_Number_Operating_Airline -0.397817      -0.395946            0.006880
# OriginAirportID                  0.081689       0.086570            0.005184
# OriginAirportSeqID               0.081689       0.086570            0.005184
# OriginCityMarketID               0.022165       0.024247           -0.000598
# OriginStateFips                 -0.085273      -0.090767            0.002195
# OriginWac                        0.025794       0.029164            0.004842
# DestAirportID                    0.081561       0.086409           -0.003801
# DestAirportSeqID                 0.081562       0.086409           -0.003801
# DestCityMarketID                 0.021831       0.023868            0.002890
# DestStateFips                   -0.085792      -0.091255            0.004891
# DestWac                          0.025821       0.029217            0.005202
# CRSDepTime                      -0.007776      -0.009390            0.006152
# DepTime                         -0.020027      -0.021693            0.007114
# DepDelay                         0.012566       0.012041            0.010052
# DepDelayMinutes                  0.008867       0.008347            0.009659
# DepDel15                         0.026081       0.025619            0.010662
# DepartureDelayGroups             0.018404       0.017862            0.013527
# TaxiOut                         -0.014883      -0.015733            0.011301
# WheelsOff                       -0.036725      -0.038603            0.007575
# WheelsOn                         0.024222       0.028176            0.000593
# TaxiIn                           0.056979       0.055000            0.017024
# CRSArrTime                       0.037582       0.041469            0.003102
# ArrTime                          0.020550       0.024175           -0.000585
# ArrDelay                        -0.012793      -0.013367            0.006020
# ArrDelayMinutes                  0.000831       0.000431            0.006221
# ArrDel15                         0.009940       0.009420            0.002803
# ArrivalDelayGroups              -0.007196      -0.007830            0.006861
# Cancelled                       -0.030597      -0.030275            0.051526
# Diverted                         0.011237       0.010892            0.318472
# CRSElapsedTime                   0.975438       0.963376           -0.004650
# ActualElapsedTime                0.963585       0.951355            0.003841
# AirTime                          0.981829       0.969650            0.004138
# Flights                               NaN            NaN                 NaN
# Distance                         1.000000       0.985894           -0.005017
# DistanceGroup                    0.985894       1.000000           -0.005327
# DivAirportLandings              -0.005017      -0.005327            1.000000
#
# [44 rows x 44 columns]

# %%
set(df["Quarter"])
# Out:
# {1}

# %%
corr["ArrDelay"].sort_values()[::-1][6:]
# Out:
# ArrDelay                           1.000000
# ArrDelayMinutes                    0.981186
# DepDelay                           0.961473
# DepDelayMinutes                    0.958868
# ArrivalDelayGroups                 0.853398
# DepartureDelayGroups               0.808517
# ArrDel15                           0.601926
# DepDel15                           0.553222
# TaxiOut                            0.213216
# TaxiIn                             0.137481
# DepTime                            0.097813
# WheelsOff                          0.095082
# DOT_ID_Marketing_Airline           0.061968
# DOT_ID_Operating_Airline           0.056585
# CRSDepTime                         0.055869
# DayOfWeek                          0.047940
# ActualElapsedTime                  0.040878
# CRSArrTime                         0.039470
# WheelsOn                           0.021423
# Flight_Number_Operating_Airline    0.019418
# Flight_Number_Marketing_Airline    0.019388
# ArrTime                            0.014924
# DestStateFips                      0.010755
# DestCityMarketID                   0.007407
# DivAirportLandings                 0.006020
# OriginStateFips                    0.002974
# OriginCityMarketID                -0.001803
# AirTime                           -0.003669
# DestAirportID                     -0.003731
# DestAirportSeqID                  -0.003732
# OriginAirportID                   -0.010946
# OriginAirportSeqID                -0.010946
# Distance                          -0.012793
# DistanceGroup                     -0.013367
# CRSElapsedTime                    -0.021108
# OriginWac                         -0.027442
# DestWac                           -0.040499
# DayofMonth                        -0.125359
# Name: ArrDelay, dtype: float64

# %%
Y = df["ArrDelay                           "]
X = df["DepTime"]

# %%
df.to_csv("fichier_final.csv")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\colvray\AppData\Local\Temp\ipykernel_22760\31572796.py", line 1, in <module>
#     df.to_csv("fichier_final.csv")
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\core\generic.py", line 3551, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\format.py", line 1180, in to_csv
#     csv_formatter.save()
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 261, in save
#     self._save()
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 266, in _save
#     self._save_body()
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 304, in _save_body
#     self._save_chunk(start_i, end_i)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 315, in _save_chunk
#     libwriters.write_csv_rows(
#   File "pandas\_libs\writers.pyx", line 55, in pandas._libs.writers.write_csv_rows
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\colvray\anaconda3\lib\ntpath.py", line 664, in realpath
#     if _getfinalpathname(spath) == path:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\colvray\AppData\Local\Temp\ipykernel_22760\31572796.py", line 1, in <module>
#     df.to_csv("fichier_final.csv")
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\core\generic.py", line 3551, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\format.py", line 1180, in to_csv
#     csv_formatter.save()
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 261, in save
#     self._save()
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 266, in _save
#     self._save_body()
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 304, in _save_body
#     self._save_chunk(start_i, end_i)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 315, in _save_chunk
#     libwriters.write_csv_rows(
#   File "pandas\_libs\writers.pyx", line 55, in pandas._libs.writers.write_csv_rows
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\colvray\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\colvray\AppData\Local\Temp\ipykernel_22760\31572796.py", line 1, in <module>
#     df.to_csv("fichier_final.csv")
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\core\generic.py", line 3551, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\format.py", line 1180, in to_csv
#     csv_formatter.save()
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 261, in save
#     self._save()
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 266, in _save
#     self._save_body()
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 304, in _save_body
#     self._save_chunk(start_i, end_i)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 315, in _save_chunk
#     libwriters.write_csv_rows(
#   File "pandas\_libs\writers.pyx", line 55, in pandas._libs.writers.write_csv_rows
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\colvray\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\colvray\anaconda3\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\colvray\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt

# %%
df.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline ',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'Origin', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'Dest',
#        'DestCityName', 'DestState', 'DestStateFips', 'DestStateName',
#        'DestWac', 'CRSDepTime', 'DepTime', 'DepDelay', 'DepDelayMinutes',
#        'DepDel15', 'DepartureDelayGroups', 'DepTimeBlk', 'TaxiOut',
#        'WheelsOff', 'WheelsOn', 'TaxiIn', 'CRSArrTime', 'ArrTime', 'ArrDelay',
#        'ArrDelayMinutes', 'ArrDel15', 'ArrivalDelayGroups', 'ArrTimeBlk',
#        'Cancelled', 'Diverted', 'CRSElapsedTime', 'ActualElapsedTime',
#        'AirTime', 'Flights', 'Distance', 'DistanceGroup', 'DivAirportLandings',
#        'Duplicate'],
#       dtype='object')

# %%
df.shape
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 68
# (563737, 62)

# %%
df_min
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 480798  2022        1      1          31          1  31/01/2022
# 30261   2022        1      1          20          4  20/01/2022
# 34169   2022        1      1           8          6  08/01/2022
# 471868  2022        1      1           2          7  02/01/2022
# 284889  2022        1      1          22          6  22/01/2022
# ...      ...      ...    ...         ...        ...         ...
# 488453  2022        1      1          10          1  10/01/2022
# 563164  2022        1      1          23          7  23/01/2022
# 479438  2022        1      1          20          4  20/01/2022
# 523675  2022        1      1           3          1  03/01/2022
# 466374  2022        1      1          30          7  30/01/2022
#
#        Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 480798                        DL                            DL_CODESHARE
# 30261                         DL                                      DL
# 34169                         DL                                      DL
# 471868                        UA                            UA_CODESHARE
# 284889                        DL                            DL_CODESHARE
# ...                          ...                                     ...
# 488453                        UA                            UA_CODESHARE
# 563164                        AA                            AA_CODESHARE
# 479438                        DL                            DL_CODESHARE
# 523675                        UA                                      UA
# 466374                        UA                            UA_CODESHARE
#
#         DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ...  \
# 480798                     19790                          DL  ...
# 30261                      19790                          DL  ...
# 34169                      19790                          DL  ...
# 471868                     19977                          UA  ...
# 284889                     19790                          DL  ...
# ...                          ...                         ...  ...
# 488453                     19977                          UA  ...
# 563164                     19805                          AA  ...
# 479438                     19790                          DL  ...
# 523675                     19977                          UA  ...
# 466374                     19977                          UA  ...
#
#         Div4TailNum Div5Airport  Div5AirportID Div5AirportSeqID  Div5WheelsOn  \
# 480798          NaN         NaN            NaN              NaN           NaN
# 30261           NaN         NaN            NaN              NaN           NaN
# 34169           NaN         NaN            NaN              NaN           NaN
# 471868          NaN         NaN            NaN              NaN           NaN
# 284889          NaN         NaN            NaN              NaN           NaN
# ...             ...         ...            ...              ...           ...
# 488453          NaN         NaN            NaN              NaN           NaN
# 563164          NaN         NaN            NaN              NaN           NaN
# 479438          NaN         NaN            NaN              NaN           NaN
# 523675          NaN         NaN            NaN              NaN           NaN
# 466374          NaN         NaN            NaN              NaN           NaN
#
#        Div5TotalGTime  Div5LongestGTime Div5WheelsOff Div5TailNum  Duplicate
# 480798            NaN               NaN           NaN         NaN          N
# 30261             NaN               NaN           NaN         NaN          N
# 34169             NaN               NaN           NaN         NaN          N
# 471868            NaN               NaN           NaN         NaN          N
# 284889            NaN               NaN           NaN         NaN          N
# ...               ...               ...           ...         ...        ...
# 488453            NaN               NaN           NaN         NaN          N
# 563164            NaN               NaN           NaN         NaN          N
# 479438            NaN               NaN           NaN         NaN          N
# 523675            NaN               NaN           NaN         NaN          N
# 466374            NaN               NaN           NaN         NaN          N
#
# [10000 rows x 119 columns]

# %%
# columns_to_keep = list(df.columns[:6]) + ["CRSArrTime","ArrTime","ArrDelay","CRSArrTime"]

# %%
columns_to_keep
# Out:
# ['Year',
#  'Quarter',
#  'Month',
#  'DayofMonth',
#  'DayOfWeek',
#  'FlightDate',
#  'CRSArrTime',
#  'ArrTime',
#  'ArrDelay',
#  'CRSArrTime']

# %%
# df_min = df[columns_to_keep]

# %%
~df_min["ArrDelay"].isna()
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 563732    False
# 563733    False
# 563734    False
# 563735    False
# 563736    False
# Name: ArrDelay, Length: 563737, dtype: bool

# %%
df_min = df_min[~df_min["ArrDelay"].isna()]

# %%
import seaborn as sb
corr = df_min.corr()
sb.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
df_min=df_min.drop(columns=[])

# %%
df_min.to_csv("fichier_final.csv")

# %%
import pandas as pd 
df=pd.read_csv("flight_data_2018_to_2022.csv", sep=";" , low_memory=False )
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2022        1      1           6          4  06/01/2022
# 1  2022        1      1           6          4  06/01/2022
# 2  2022        1      1           6          4  06/01/2022
# 3  2022        1      1           6          4  06/01/2022
# 4  2022        1      1           6          4  06/01/2022
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        DL                                      DL
# 1                        DL                                      DL
# 2                        DL                                      DL
# 3                        DL                                      DL
# 4                        DL                                      DL
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ...  Div4TailNum  \
# 0                     19790                          DL  ...          NaN
# 1                     19790                          DL  ...          NaN
# 2                     19790                          DL  ...          NaN
# 3                     19790                          DL  ...          NaN
# 4                     19790                          DL  ...          NaN
#
#   Div5Airport  Div5AirportID Div5AirportSeqID  Div5WheelsOn Div5TotalGTime  \
# 0         NaN            NaN              NaN           NaN            NaN
# 1         NaN            NaN              NaN           NaN            NaN
# 2         NaN            NaN              NaN           NaN            NaN
# 3         NaN            NaN              NaN           NaN            NaN
# 4         NaN            NaN              NaN           NaN            NaN
#
#    Div5LongestGTime Div5WheelsOff Div5TailNum  Duplicate
# 0               NaN           NaN         NaN          N
# 1               NaN           NaN         NaN          N
# 2               NaN           NaN         NaN          N
# 3               NaN           NaN         NaN          N
# 4               NaN           NaN         NaN          N
#
# [5 rows x 119 columns]
