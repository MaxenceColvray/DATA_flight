# %%
import pandas as pd 
df=pd.read_csv("flight_data_2018_to_2022.csv", sep=";" , low_memory=False )

# %%
df_min=df.sample(10000)

# %%
df_min.to_csv("sample10000.csv")

# %%
df_min.isna()
# Out:
#          Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 534394  False    False  False       False      False       False
# 112740  False    False  False       False      False       False
# 263818  False    False  False       False      False       False
# 62150   False    False  False       False      False       False
# 11007   False    False  False       False      False       False
# ...       ...      ...    ...         ...        ...         ...
# 102516  False    False  False       False      False       False
# 151172  False    False  False       False      False       False
# 25098   False    False  False       False      False       False
# 72761   False    False  False       False      False       False
# 381698  False    False  False       False      False       False
#
#         Marketing_Airline_Network  Operated_or_Branded_Code_Share_Partners  \
# 534394                      False                                    False
# 112740                      False                                    False
# 263818                      False                                    False
# 62150                       False                                    False
# 11007                       False                                    False
# ...                           ...                                      ...
# 102516                      False                                    False
# 151172                      False                                    False
# 25098                       False                                    False
# 72761                       False                                    False
# 381698                      False                                    False
#
#         DOT_ID_Marketing_Airline  IATA_Code_Marketing_Airline  ...  \
# 534394                     False                        False  ...
# 112740                     False                        False  ...
# 263818                     False                        False  ...
# 62150                      False                        False  ...
# 11007                      False                        False  ...
# ...                          ...                          ...  ...
# 102516                     False                        False  ...
# 151172                     False                        False  ...
# 25098                      False                        False  ...
# 72761                      False                        False  ...
# 381698                     False                        False  ...
#
#         Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID  \
# 534394         True         True           True              True
# 112740         True         True           True              True
# 263818         True         True           True              True
# 62150          True         True           True              True
# 11007          True         True           True              True
# ...             ...          ...            ...               ...
# 102516         True         True           True              True
# 151172         True         True           True              True
# 25098          True         True           True              True
# 72761          True         True           True              True
# 381698         True         True           True              True
#
#         Div5WheelsOn  Div5TotalGTime  Div5LongestGTime  Div5WheelsOff  \
# 534394          True            True              True           True
# 112740          True            True              True           True
# 263818          True            True              True           True
# 62150           True            True              True           True
# 11007           True            True              True           True
# ...              ...             ...               ...            ...
# 102516          True            True              True           True
# 151172          True            True              True           True
# 25098           True            True              True           True
# 72761           True            True              True           True
# 381698          True            True              True           True
#
#         Div5TailNum  Duplicate
# 534394         True      False
# 112740         True      False
# 263818         True      False
# 62150          True      False
# 11007          True      False
# ...             ...        ...
# 102516         True      False
# 151172         True      False
# 25098          True      False
# 72761          True      False
# 381698         True      False
#
# [10000 rows x 119 columns]

# %%
ratio_na=(df_min.isna().sum()/df_min.shape[0])

# %%
ratio_na.to_csv("ratio_na.csv")

# %%
columns_useful=ratio_na[ratio_na<0.5].index

# %%
df=df[columns_useful]

# %%
df.to_csv("fichier_final.csv")

# %%
df.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline ',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'Origin', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'Dest',
#        'DestCityName', 'DestState', 'DestStateFips', 'DestStateName',
#        'DestWac', 'CRSDepTime', 'DepTime', 'DepDelay', 'DepDelayMinutes',
#        'DepDel15', 'DepartureDelayGroups', 'DepTimeBlk', 'TaxiOut',
#        'WheelsOff', 'WheelsOn', 'TaxiIn', 'CRSArrTime', 'ArrTime', 'ArrDelay',
#        'ArrDelayMinutes', 'ArrDel15', 'ArrivalDelayGroups', 'ArrTimeBlk',
#        'Cancelled', 'Diverted', 'CRSElapsedTime', 'ActualElapsedTime',
#        'AirTime', 'Flights', 'Distance', 'DistanceGroup', 'DivAirportLandings',
#        'Duplicate'],
#       dtype='object')

# %%
df.shape
# Out:
# (563737, 62)

# %%
import seaborn as sb
corr = df.corr()
sb.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
df_min=df_min.drop(columns=[])

# %%
df_min.to_csv("fichier_final.csv")
